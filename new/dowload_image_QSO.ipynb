# %%
#For QSO
from utils import *
#import pandas as pd
w =16
data_path = '../data/csvs/QSO/QSO2.csv'
dir_save = '../data/images/QSO1/all/'
save_preprocessing_images(data_path, dir_save, w, 1);
# Out:
# starting ......
# Leading of object number :  1
# ------| leading of band  u
# ------| leading of band  g
# ------| leading of band  r
# ------| leading of band  i
# ------| leading of band  z
# Leading of object number :  2
# ------| leading of band  u
# ------| leading of band  g
# ------| leading of band  r
# ------| leading of band  i
# ------| leading of band  z
# Leading of object number :  3
# ------| leading of band  u
# ------| leading of band  g
# ------| leading of band  r
# ------| leading of band  i
# ------| leading of band  z
# Leading of object number :  4
# ------| leading of band  u
# ------| leading of band  g
# ------| leading of band  r
# ------| leading of band  i
# ------| leading of band  z
# Leading of object number :  5
# ------| leading of band  u
# ------| leading of band  g
# ------| leading of band  r
# ------| leading of band  i
# ------| leading of band  z
# Leading of object number :  6
# ------| leading of band  u
# ------| leading of band  g
# ...
